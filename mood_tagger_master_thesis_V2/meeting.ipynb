# %%
from data import baseline
import infer

# %% [markdown]
# Mean values of GEMS scores.
# Error values when predicting mean values.

# %%
baseline.mean_value_predictor()
# Out:
# Mean values:
# Wonder           13.282973
# Transcendence     9.536189
# Nostalgia        13.177081
# Tenderness        9.475270
# Peacfulness      15.062568
# Joy              19.696595
# Power            12.221919
# Tension           8.125811
# Sadness           3.240432
# dtype: float64
# for 370 test samples:
#           Wonder Transcendence Nostalgia Tenderness Peacfulness Joy Power Tension Sadness
# mean err: [-0. 	  0. 	 -0. 	 -0. 	  0. 	  0. 	 -0. 	 -0. 	 -0.]
# m abs er: [4.79 	 4.42 	 7.48 	 6.28 	 8.08 	 8.66 	 7.24 	 5.08 	 3.31]
# m squared er: [ 36.96 	  29.97 	  82.84 	  58.55 	 103.71 	 111.85 	  79.05 	  45.
#   24.26]
# root m squared er: [ 6.08 	  5.47 	  9.1  	  7.65 	 10.18 	 10.58 	  8.89 	  6.71 	  4.93]
# maximums: [23.93 	 22.62 	 27.53 	 25.49 	 33.1  	 31.34 	 35.12 	 26.66 	 26.7 ]
# minimums: [-13.28 	  -9.54 	 -13.18 	  -9.48 	 -15.06 	 -19.7  	 -12.22 	  -8.13
#   -3.24]
#
# overall:
# ME: -0.00
# MAE: 6.15
# MSE: 63.57
# RMSE: 7.73

# %% [markdown]
# allconv01

# %%
infer.run('/home/ykinoshita/humrec_mood_tagger/outputs/2023-06-21/13-16-05' )
# Out:
# not found! Black Hippy Control
# not found! Naughty by Nature O.P.P.
# not found! Busta Rhymes Put Your Hands Where My Eyes Can See
# not found! Method Man Part II
# not found! Mahler 6. Sinfonie, 1. Satz
# not found count :  5   - matched: 365
# INFO:root:Number of total training examples: 532.
# Annotation:[19.7   5.93  7.1   1.68 17.02 47.74 32.13  6.57  0.  ]
# Prediction:['12.63', '6.72', '9.67', '5.50', '9.06', '24.81', '14.74', '8.46', '2.06']
# Mean: [13.28, 9.53, 13.17, 9.47, 15.06, 19.69, 12.22, 8.12, 3.24]
#
# Annotation:[25.61  8.83 26.76  8.88 17.57 38.04 11.06  2.87  0.  ]
# Prediction:['13.97', '7.43', '11.60', '7.32', '10.03', '24.61', '15.22', '8.28', '2.69']
# Mean: [13.28, 9.53, 13.17, 9.47, 15.06, 19.69, 12.22, 8.12, 3.24]
#
# Annotation:[ 8.88 12.87 12.19  3.23  4.71 19.84 23.18 11.72  4.03]
# Prediction:['14.69', '8.97', '12.29', '7.98', '11.44', '23.98', '14.82', '8.77', '2.64']
# Mean: [13.28, 9.53, 13.17, 9.47, 15.06, 19.69, 12.22, 8.12, 3.24]
#
# ...

# %% [markdown]
# Musicnn shorter seconds

# %%
infer.run("/home/ykinoshita/humrec_mood_tagger/outputs/2023-07-18/14-59-43")
# Out:
# INFO:root:Number of total training examples: 2725.
# not found! Black Hippy Control
# not found! Naughty by Nature O.P.P.
# not found! Busta Rhymes Put Your Hands Where My Eyes Can See
# not found! Method Man Part II
# not found! Mahler 6. Sinfonie, 1. Satz
# not found count :  5   - matched: 365
# Annotation:[19.7   5.93  7.1   1.68 17.02 47.74 32.13  6.57  0.  ]
# Prediction:['10.89', '4.58', '6.18', '2.48', '6.33', '31.80', '16.34', '10.59', '3.64']
# Mean: [13.28, 9.53, 13.17, 9.47, 15.06, 19.69, 12.22, 8.12, 3.24]
#
# Annotation:[25.61  8.83 26.76  8.88 17.57 38.04 11.06  2.87  0.  ]
# Prediction:['11.32', '6.27', '8.51', '5.19', '9.61', '27.49', '14.24', '9.31', '3.63']
# Mean: [13.28, 9.53, 13.17, 9.47, 15.06, 19.69, 12.22, 8.12, 3.24]
#
# Annotation:[ 8.88 12.87 12.19  3.23  4.71 19.84 23.18 11.72  4.03]
# Prediction:['11.83', '7.38', '9.84', '6.71', '11.76', '25.32', '13.26', '8.56', '3.90']
# Mean: [13.28, 9.53, 13.17, 9.47, 15.06, 19.69, 12.22, 8.12, 3.24]
#
# ...

# %% [markdown]
# log transformed

# %%
infer.run('/home/ykinoshita/humrec_mood_tagger/outputs/2023-07-12/17-13-56')
# Out:
# INFO:root:Number of total training examples: 2725.
# not found! Black Hippy Control
# not found! Naughty by Nature O.P.P.
# not found! Busta Rhymes Put Your Hands Where My Eyes Can See
# not found! Method Man Part II
# not found! Mahler 6. Sinfonie, 1. Satz
# not found count :  5   - matched: 365
# Output data is log transform, applying np.exp to output.
# Annotation:[19.7   5.93  7.1   1.68 17.02 47.74 32.13  6.57  0.  ]
# Prediction:['9.27', '6.44', '4.47', '3.17', '7.00', '26.79', '17.92', '11.06', '1.33']
# Mean: [13.28, 9.53, 13.17, 9.47, 15.06, 19.69, 12.22, 8.12, 3.24]
#
# Annotation:[25.61  8.83 26.76  8.88 17.57 38.04 11.06  2.87  0.  ]
# Prediction:['16.24', '9.04', '10.92', '6.97', '10.05', '29.10', '24.87', '8.58', '2.51']
# Mean: [13.28, 9.53, 13.17, 9.47, 15.06, 19.69, 12.22, 8.12, 3.24]
#
# Annotation:[ 8.88 12.87 12.19  3.23  4.71 19.84 23.18 11.72  4.03]
# Prediction:['12.11', '8.03', '8.83', '6.65', '10.71', '22.24', '15.43', '10.50', '2.04']
# ...

# %%
infer.run('/home/ykinoshita/humrec_mood_tagger/outputs/2023-07-18/16-49-44')
# Out:
# INFO:root:Number of total training examples: 532.
# not found! Black Hippy Control
# not found! Naughty by Nature O.P.P.
# not found! Busta Rhymes Put Your Hands Where My Eyes Can See
# not found! Method Man Part II
# not found! Mahler 6. Sinfonie, 1. Satz
# not found count :  5   - matched: 365
# Output data is log transform, applying np.exp to output.
# Annotation:[19.7   5.93  7.1   1.68 17.02 47.74 32.13  6.57  0.  ]
# Prediction:['12.22', '6.61', '6.85', '3.57', '7.22', '28.93', '16.09', '9.07', '1.92']
# Mean: [13.28, 9.53, 13.17, 9.47, 15.06, 19.69, 12.22, 8.12, 3.24]
#
# Annotation:[25.61  8.83 26.76  8.88 17.57 38.04 11.06  2.87  0.  ]
# Prediction:['13.92', '8.96', '9.98', '6.37', '9.22', '23.65', '16.14', '9.65', '3.03']
# Mean: [13.28, 9.53, 13.17, 9.47, 15.06, 19.69, 12.22, 8.12, 3.24]
#
# Annotation:[ 8.88 12.87 12.19  3.23  4.71 19.84 23.18 11.72  4.03]
# Prediction:['13.19', '7.63', '10.42', '5.82', '10.62', '22.90', '12.47', '7.53', '2.68']
# ...

# %%
import pandas as pd

synonyms = pd.read_pickle(r'/home/ykinoshita/humrec_mood_tagger/mood_tagger_master_thesis_V2/data/additional_data/synonyms_dict.pkl')

# %%
gems_items = pd.read_pickle(r'/home/ykinoshita/humrec_mood_tagger/mood_tagger_master_thesis_V2/data/additional_data/gems_items.pkl')
gems_items
# Out:
# {'wonder': ['moved',
#   'filled with wonder',
#   'allured',
#   'happy',
#   'dazzled',
#   'admiring'],
#  'transcendence': ['fascinated',
#   'overwhelmed',
#   'feeling of transcendence',
#   'inspired',
#   'chills (shivers & goose bumps)',
#   'feeling of spirituality'],
#  'energy': ['strong', 'energetic', 'triumphant', 'fiery', 'heroic'],
#  'tenderness': ['tender',
#   'affectionate',
#   'mellowed (softened-up)',
#   'in love',
#   'sensual'],
#  'nostalgia': ['nostalgic', 'sentimental', 'dreamy', 'melancholic'],
#  'peacefulness': ['serene', 'calm', 'soothed', 'meditative', 'relaxed'],
#  'joyful_activation': ['animated',
#   'bouncy',
#   'joyful',
#   'feel like dancing',
#   'amused',
#   'stimulated'],
#  'sadness': ['sad', 'tearful', 'sorrowful'],
#  'tension': ['tense', 'agitated', 'irritated', 'nervous', 'impatient']}

# %%
pd.read_csv('/home/ykinoshita/humrec_mood_tagger/mood_tagger_master_thesis_V2/data/additional_data/EMMA_dataselected_summarized.csv')
# Out:
#      Song  Gs_1  Gs_2  Gs_3  Gs_4  Gs_5  Gs_6  Gs_7  Gs_8  Gs_9  ...  Gs_40  \
# 0    H001     1     3     0     0     1     0     5     0     1  ...      2
# 1    H002     2     1     2     1     1     1     2     0     1  ...      1
# 2    H003     3     2     4     0     3     0     1     0     0  ...      0
# 3    H004     1     0     2     1     1     0     2     0     0  ...      0
# 4    H005     0     3     3     0     0     1     0     0     0  ...      1
# ..    ...   ...   ...   ...   ...   ...   ...   ...   ...   ...  ...    ...
# 359  P142     3     0     2     3    11     2     4     5     1  ...      0
# 360  P143     2     3     2     0     0     1     6     0     4  ...      0
# 361  P144     1     0     1     2     6     1     3     0     1  ...      0
# 362  P145     1     2     1     3     2     4     1     2     0  ...      3
# 363  P146     5     1     6     2     8     4     1     1     0  ...      2
#
# ...
