# %%
3//2
# Out:
# 1

# %%
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df = pd.read_csv('/home/ykinoshita/humrec_mood_tagger/mood_tagger_master_thesis_V2/performance/model_performance_list_detailed.csv')

# %%
df.tail()
# Out:
#            Model                                             Labels    lr  \
# 282  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 283  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 284  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 285  FCN_7_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 286  FCN_7_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
#
#           loss_function  dense_weight_alpha  batch size  data_augmentation  \
# 282        dense_weight                 1.0          50                  0
# 283  dense_weight_tuned                 0.0          50                  0
# 284        dense_weight                 1.5          50                  0
# 285        dense_weight                 1.5          50                  0
# 286        dense_weight                 2.0          50                  0
#
#      snippet_duration_s  oversampling  oversampling_tolerance  \
# ...

# %%
condition =( df['Labels'] =="['Wonder']") | ( df['Labels'] =="['Wonder', 'Transcendence', 'Nostalgia', 'Tenderness', 'Peacfulness', 'Joy', 'Power', 'Tension', 'Sadness']")  
df[condition].sort_values('Wonder MAE')
# Out:
#                             Model  \
# 175  Transfer_learning_embeddings
# 246  Transfer_learning_embeddings
# 196  Transfer_learning_embeddings
# 179  Transfer_learning_embeddings
# 245  Transfer_learning_embeddings
# 92                    FCN_4_layer
# 144                   FCN_6_layer
# 106                   FCN_5_layer
# 141                   FCN_5_layer
# 133                   FCN_6_layer
# 134                   FCN_4_layer
# 90                multitask_model
# 165                   FCN_6_layer
# 140                   FCN_5_layer
# 122                   FCN_4_layer
# 145                   FCN_6_layer
# 129                   FCN_4_layer
# 148                   FCN_6_layer
# 150                   FCN_4_layer
# 88                    FCN_5_layer
# 146                   FCN_6_layer
# 147                   FCN_6_layer
# 100                   FCN_6_layer
# 101                   FCN_6_layer
# 103                   FCN_4_layer
# 149                   FCN_5_layer
# ...

# %%
condition =( df['Labels'] =="['Transcendence']")| ( df['Labels'] =="['Wonder', 'Transcendence', 'Nostalgia', 'Tenderness', 'Peacfulness', 'Joy', 'Power', 'Tension', 'Sadness']")  
df[condition].sort_values('Transcendence MAE')
# Out:
#                             Model  \
# 197  Transfer_learning_embeddings
# 175  Transfer_learning_embeddings
# 108                   FCN_5_layer
# 179  Transfer_learning_embeddings
# 124                   FCN_5_layer
# 149                   FCN_5_layer
# 20                     allconv_01
# 98                    FCN_5_layer
# 215                   FCN_6_layer
# 247  Transfer_learning_embeddings
# 127                   FCN_6_layer
# 84                     allconv_01
# 120                   FCN_4_layer
# 148                   FCN_6_layer
# 91                    FCN_5_layer
# 187                   FCN_6_layer
# 136                   FCN_6_layer
# 101                   FCN_6_layer
# 3                      allconv_01
# 150                   FCN_4_layer
# 135                   FCN_5_layer
# 141                   FCN_5_layer
# 106                   FCN_5_layer
# 92                    FCN_4_layer
# 134                   FCN_4_layer
# 81                     allconv_01
# ...

# %%
condition =( df['Labels'] =="['Nostalgia']")| ( df['Labels'] =="['Wonder', 'Transcendence', 'Nostalgia', 'Tenderness', 'Peacfulness', 'Joy', 'Power', 'Tension', 'Sadness']")  
df[condition].sort_values('Nostalgia MAE')
# Out:
#                             Model  \
# 148                   FCN_6_layer
# 102                   FCN_6_layer
# 0                      allconv_01
# 127                   FCN_6_layer
# 144                   FCN_6_layer
# 96                    FCN_4_layer
# 143                   FCN_6_layer
# 76                     allconv_01
# 175  Transfer_learning_embeddings
# 188                   FCN_6_layer
# 145                   FCN_6_layer
# 283                   FCN_6_layer
# 147                   FCN_6_layer
# 146                   FCN_6_layer
# 100                   FCN_6_layer
# 167                   FCN_6_layer
# 124                   FCN_5_layer
# 101                   FCN_6_layer
# 125                   FCN_5_layer
# 119                   FCN_6_layer
# 134                   FCN_4_layer
# 103                   FCN_4_layer
# 140                   FCN_5_layer
# 49                     allconv_01
# 136                   FCN_6_layer
# 104                   FCN_4_layer
# ...

# %%
condition =( df['Labels'] =="['Tenderness']")| ( df['Labels'] =="['Wonder', 'Transcendence', 'Nostalgia', 'Tenderness', 'Peacfulness', 'Joy', 'Power', 'Tension', 'Sadness']")  
df[condition].sort_values('Tenderness MAE')
# Out:
#                             Model  \
# 140                   FCN_5_layer
# 148                   FCN_6_layer
# 145                   FCN_6_layer
# 102                   FCN_6_layer
# 136                   FCN_6_layer
# 135                   FCN_5_layer
# 122                   FCN_4_layer
# 88                    FCN_5_layer
# 126                   FCN_6_layer
# 101                   FCN_6_layer
# 94                    FCN_4_layer
# 89                    FCN_4_layer
# 50                     allconv_01
# 151                   FCN_7_layer
# 96                    FCN_4_layer
# 107                   FCN_5_layer
# 104                   FCN_4_layer
# 175  Transfer_learning_embeddings
# 119                   FCN_6_layer
# 144                   FCN_6_layer
# 127                   FCN_6_layer
# 230                   FCN_6_layer
# 98                    FCN_5_layer
# 95                    FCN_4_layer
# 105                   FCN_4_layer
# 90                multitask_model
# ...

# %%
condition =( df['Labels'] =="['Peacfulness']")| ( df['Labels'] =="['Wonder', 'Transcendence', 'Nostalgia', 'Tenderness', 'Peacfulness', 'Joy', 'Power', 'Tension', 'Sadness']")  
df[condition].sort_values('Peacfulness MAE')
# Out:
#                             Model  \
# 140                   FCN_5_layer
# 123                   FCN_5_layer
# 93                    FCN_4_layer
# 101                   FCN_6_layer
# 100                   FCN_6_layer
# 92                    FCN_4_layer
# 118                   FCN_6_layer
# 98                    FCN_5_layer
# 95                    FCN_4_layer
# 109                   FCN_6_layer
# 127                   FCN_6_layer
# 119                   FCN_6_layer
# 158                   FCN_6_layer
# 104                   FCN_4_layer
# 175  Transfer_learning_embeddings
# 23                     allconv_01
# 88                    FCN_5_layer
# 283                   FCN_6_layer
# 150                   FCN_4_layer
# 125                   FCN_5_layer
# 143                   FCN_6_layer
# 124                   FCN_5_layer
# 164               multitask_model
# 145                   FCN_6_layer
# 110                   FCN_6_layer
# 148                   FCN_6_layer
# ...

# %%
condition =( df['Labels'] =="['Joy']")| ( df['Labels'] =="['Wonder', 'Transcendence', 'Nostalgia', 'Tenderness', 'Peacfulness', 'Joy', 'Power', 'Tension', 'Sadness']")  
df[condition].sort_values('Joy MAE')
# Out:
#                             Model  \
# 2                 multitask_model
# 100                   FCN_6_layer
# 92                    FCN_4_layer
# 179  Transfer_learning_embeddings
# 133                   FCN_6_layer
# 251  Transfer_learning_embeddings
# 147                   FCN_6_layer
# 146                   FCN_6_layer
# 148                   FCN_6_layer
# 106                   FCN_5_layer
# 181                   FCN_6_layer
# 3                      allconv_01
# 126                   FCN_6_layer
# 91                    FCN_5_layer
# 135                   FCN_5_layer
# 128                   FCN_6_layer
# 97                    FCN_5_layer
# 284                   FCN_6_layer
# 127                   FCN_6_layer
# 80                     allconv_01
# 132                   FCN_5_layer
# 78                     allconv_01
# 81                     allconv_01
# 174                   FCN_6_layer
# 164               multitask_model
# 159                   FCN_6_layer
# ...

# %%
condition =( df['Labels'] =="['Power']")| ( df['Labels'] =="['Wonder', 'Transcendence', 'Nostalgia', 'Tenderness', 'Peacfulness', 'Joy', 'Power', 'Tension', 'Sadness']")  
df[condition].sort_values('Power MAE')
# Out:
#                             Model  \
# 179  Transfer_learning_embeddings
# 175  Transfer_learning_embeddings
# 135                   FCN_5_layer
# 273  Transfer_learning_embeddings
# 252  Transfer_learning_embeddings
# 106                   FCN_5_layer
# 97                    FCN_5_layer
# 91                    FCN_5_layer
# 93                    FCN_4_layer
# 130                   FCN_5_layer
# 123                   FCN_5_layer
# 140                   FCN_5_layer
# 34                     allconv_01
# 0                      allconv_01
# 92                    FCN_4_layer
# 1                 multitask_model
# 202  Transfer_learning_embeddings
# 100                   FCN_6_layer
# 107                   FCN_5_layer
# 128                   FCN_6_layer
# 95                    FCN_4_layer
# 137                   FCN_4_layer
# 53                     allconv_01
# 132                   FCN_5_layer
# 215                   FCN_6_layer
# 131                   FCN_4_layer
# ...

# %%
condition =( df['Labels'] =="['Tension']")| ( df['Labels'] =="['Wonder', 'Transcendence', 'Nostalgia', 'Tenderness', 'Peacfulness', 'Joy', 'Power', 'Tension', 'Sadness']")  
df[condition].sort_values('Tension MAE')
# Out:
#                             Model  \
# 179  Transfer_learning_embeddings
# 101                   FCN_6_layer
# 175  Transfer_learning_embeddings
# 148                   FCN_6_layer
# 110                   FCN_6_layer
# 128                   FCN_6_layer
# 126                   FCN_6_layer
# 103                   FCN_4_layer
# 133                   FCN_6_layer
# 145                   FCN_6_layer
# 144                   FCN_6_layer
# 100                   FCN_6_layer
# 0                      allconv_01
# 127                   FCN_6_layer
# 104                   FCN_4_layer
# 151                   FCN_7_layer
# 99                    FCN_5_layer
# 125                   FCN_5_layer
# 112                   FCN_4_layer
# 134                   FCN_4_layer
# 107                   FCN_5_layer
# 282                   FCN_6_layer
# 136                   FCN_6_layer
# 225                   FCN_6_layer
# 108                   FCN_5_layer
# 150                   FCN_4_layer
# ...

# %%
condition =( df['Labels'] =="['Sadness']")| ( df['Labels'] =="['Wonder', 'Transcendence', 'Nostalgia', 'Tenderness', 'Peacfulness', 'Joy', 'Power', 'Tension', 'Sadness']")  
df[condition].sort_values('Sadness MAE')
# Out:
#                             Model  \
# 101                   FCN_6_layer
# 144                   FCN_6_layer
# 99                    FCN_5_layer
# 194                   FCN_6_layer
# 145                   FCN_6_layer
# 102                   FCN_6_layer
# 142                   FCN_5_layer
# 148                   FCN_6_layer
# 108                   FCN_5_layer
# 151                   FCN_7_layer
# 140                   FCN_5_layer
# 134                   FCN_4_layer
# 152   pretrained_musicnn_parallel
# 95                    FCN_4_layer
# 162                   FCN_6_layer
# 27                     allconv_01
# 100                   FCN_6_layer
# 139                   FCN_4_layer
# 181                   FCN_6_layer
# 183               short_chunk_CNN
# 111                   FCN_4_layer
# 0                      allconv_01
# 1                 multitask_model
# 104                   FCN_4_layer
# 174                   FCN_6_layer
# 146                   FCN_6_layer
# ...

# %%
condition =( df['Labels'] =="['Wonder', 'Transcendence', 'Nostalgia', 'Tenderness', 'Peacfulness', 'Joy', 'Power', 'Tension', 'Sadness']")  


df[condition].sort_values('RMSE')
# Out:
#                             Model  \
# 175  Transfer_learning_embeddings
# 179  Transfer_learning_embeddings
# 148                   FCN_6_layer
# 101                   FCN_6_layer
# 127                   FCN_6_layer
# 0                      allconv_01
# 125                   FCN_5_layer
# 107                   FCN_5_layer
# 126                   FCN_6_layer
# 140                   FCN_5_layer
# 102                   FCN_6_layer
# 123                   FCN_5_layer
# 100                   FCN_6_layer
# 144                   FCN_6_layer
# 145                   FCN_6_layer
# 146                   FCN_6_layer
# 147                   FCN_6_layer
# 181                   FCN_6_layer
# 95                    FCN_4_layer
# 128                   FCN_6_layer
# 135                   FCN_5_layer
# 92                    FCN_4_layer
# 104                   FCN_4_layer
# 97                    FCN_5_layer
# 136                   FCN_6_layer
# 103                   FCN_4_layer
# ...

# %%
condition =( df['Labels'] =="['Wonder', 'Transcendence', 'Nostalgia', 'Tenderness', 'Peacfulness', 'Joy', 'Power', 'Tension', 'Sadness']")  


df[condition].sort_values('MAE').iloc[[0,8,10]]
# Out:
#                             Model  \
# 175  Transfer_learning_embeddings
# 145                   FCN_6_layer
# 126                   FCN_6_layer
#
#                                                 Labels     lr loss_function  \
# 175  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.001           MAE
# 145  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.010         RMSLE
# 126  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.010  dense_weight
#
#      dense_weight_alpha  batch size  data_augmentation  snippet_duration_s  \
# 175                 0.0          10                  0             2.00000
# 145                 0.0          50                  4            29.98576
# 126                 0.0          50                  1            29.98576
#
#      oversampling  oversampling_tolerance  oversampling_ratio  \
# 175         False                     0.0                   0
# 145         False                     0.0                   0
# ...

# %%
df[condition].sort_values('MAE').iloc[[4]]
# Out:
#            Model                                             Labels    lr  \
# 100  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
#
#     loss_function  dense_weight_alpha  batch size  data_augmentation  \
# 100           MAE                 0.0          50                  1
#
#      snippet_duration_s  oversampling  oversampling_tolerance  \
# 100            29.98576         False                     0.0
#
#      oversampling_ratio oversampling_method    R2        ME       MAE  \
# 100                   0     No oversampling  99.0  0.117501  4.595829
#
#            MSE      RMSE  Wonder MAE  Transcendence MAE  Nostalgia MAE  \
# 100  41.391068  6.264326    4.954403           3.410362       4.996912
#
#      Tenderness MAE  Peacfulness MAE  Joy MAE  Power MAE  Tension MAE  \
# 100        4.394015         5.432138  6.45116   5.155626     4.493719
#
#      Sadness MAE  Wonder RMSE  Transcendence RMSE  Nostalgia RMSE  \
# ...

# %% [markdown]
# alphas = [0, 0, 0, 0.2, 0.2, 2.2, 2,1, 0.2, 0.31]
#  [False, True, False, False, False, False, True, True, True]
# 'Wonder', 'Transcendence', 'Nostalgia', 'Tenderness', 'Peacfulness', 'Joy', 'Power', 'Tension', 'Sadness'
#  4.878683	3.219061	5.09528	4.6367	6.187194	7.743399	6.116162	4.581555	2.361248
# MAE 4.97992
#  RMSE	6.579691

# %%
df
# Out:
#                             Model  \
# 0                      allconv_01
# 1                 multitask_model
# 2                 multitask_model
# 3                      allconv_01
# 4                 multitask_model
# 5                      allconv_01
# 6                 multitask_model
# 7                      allconv_01
# 8                 multitask_model
# 9                      allconv_01
# 10                     allconv_01
# 11                     allconv_01
# 12                     allconv_01
# 13                     allconv_01
# 14                     allconv_01
# 15                     allconv_01
# 16                     allconv_01
# 17                     allconv_01
# 18                     allconv_01
# 19                     allconv_01
# 20                     allconv_01
# 21                     allconv_01
# 22                     allconv_01
# 23                     allconv_01
# 24                     allconv_01
# 25                     allconv_01
# ...

# %%
condition =( df['Labels'] =="['Wonder', 'Transcendence', 'Nostalgia', 'Tenderness', 'Peacfulness', 'Joy', 'Power', 'Tension', 'Sadness']")  & (df['Model'] == 'FCN_6_layer')


df[condition].sort_values('RMSE')
# Out:
#            Model                                             Labels    lr  \
# 148  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 101  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 127  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 126  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 102  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 100  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 144  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 145  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 147  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 146  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 181  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 128  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# ...

# %%
condition =( df['Labels'] =="['Wonder', 'Transcendence', 'Nostalgia', 'Tenderness', 'Peacfulness', 'Joy', 'Power', 'Tension', 'Sadness']")  & (df['Model'] == 'FCN_5_layer')


df[condition].sort_values('RMSE')
# Out:
#            Model                                             Labels    lr  \
# 125  FCN_5_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 107  FCN_5_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 140  FCN_5_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 123  FCN_5_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 135  FCN_5_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 97   FCN_5_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 98   FCN_5_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 106  FCN_5_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 124  FCN_5_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 132  FCN_5_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 91   FCN_5_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 108  FCN_5_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# ...

# %%
condition =( df['Labels'] =="['Wonder', 'Transcendence', 'Nostalgia', 'Tenderness', 'Peacfulness', 'Joy', 'Power', 'Tension', 'Sadness']")  & (df['Model'] == 'FCN_4_layer')


df[condition].sort_values('RMSE')
# Out:
#            Model                                             Labels    lr  \
# 95   FCN_4_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 92   FCN_4_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 104  FCN_4_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 103  FCN_4_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 150  FCN_4_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 134  FCN_4_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 122  FCN_4_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 131  FCN_4_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 94   FCN_4_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 120  FCN_4_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 121  FCN_4_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 93   FCN_4_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# ...

# %%
condition =( df['Labels'] =="['Wonder', 'Transcendence', 'Nostalgia', 'Tenderness', 'Peacfulness', 'Joy', 'Power', 'Tension', 'Sadness']")


df[condition].sort_values('RMSE')
# Out:
#                             Model  \
# 175  Transfer_learning_embeddings
# 179  Transfer_learning_embeddings
# 148                   FCN_6_layer
# 101                   FCN_6_layer
# 127                   FCN_6_layer
# 0                      allconv_01
# 125                   FCN_5_layer
# 107                   FCN_5_layer
# 126                   FCN_6_layer
# 140                   FCN_5_layer
# 102                   FCN_6_layer
# 123                   FCN_5_layer
# 100                   FCN_6_layer
# 144                   FCN_6_layer
# 145                   FCN_6_layer
# 146                   FCN_6_layer
# 147                   FCN_6_layer
# 181                   FCN_6_layer
# 95                    FCN_4_layer
# 128                   FCN_6_layer
# 135                   FCN_5_layer
# 92                    FCN_4_layer
# 104                   FCN_4_layer
# 97                    FCN_5_layer
# 136                   FCN_6_layer
# 103                   FCN_4_layer
# ...

# %%
# new_column_name = 'data_augmentation'
# new_column_value = '[]'

# # # Use the insert method to add the new column at the specified location
# df.insert(6, new_column_name, new_column_value)

# %%
#df.to_csv('/home/ykinoshita/humrec_mood_tagger/mood_tagger_master_thesis_V2/performance/model_performance_list_detailed.csv', index=False)

# %%
# test = ['test','asdf']
# 'df' in test
