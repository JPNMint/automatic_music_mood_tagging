# %%
from create_binary_annotations import create_binary

# %%
create_binary(plot = True)
# Out:
# Emotion Wonder will use 20th percentile as threshold
# Emotion Transcendence will use 20th percentile as threshold
# Emotion Nostalgia will use 20th percentile as threshold
# Emotion Tenderness will use 20th percentile as threshold
# Emotion Peacfulness will use 20th percentile as threshold
# Emotion Joy will use 25th percentile as threshold
# Emotion Power will use 20th percentile as threshold
# Emotion Tension will use 10th percentile as threshold
# Emotion Sadness will use 10th percentile as threshold
# /home/ykinoshita/humrec_mood_tagger/mood_tagger_master_thesis_V2/data/create_binary_annotations.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emma_df_binary[col] = (emma_df[col] > threshold).astype(int)
# ...
