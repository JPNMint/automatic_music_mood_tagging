# %%
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df = pd.read_csv('/home/ykinoshita/humrec_mood_tagger/mood_tagger_master_thesis_V2/performance/model_performance_list_detailed.csv')

# %%
pd.read_csv('/home/ykinoshita/humrec_mood_tagger/output_fold/FCN_6_layer/No_oversampling/fold_metrics_detailed.csv')
# Out:
#          Model                                             Labels    lr  \
# 0  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 1  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 2  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 3  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 4  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 5  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 6  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 7  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 8  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 9  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
#
#   loss_function  dense_weight_alpha  batch size  snippet_duration_s  \
# 0           MAE                   0          50            29.98576
# ...

# %%
df[df['loss_function'] == 'dense_weight']
# Out:
#                             Model  \
# 2                 multitask_model
# 3                      allconv_01
# 4                 multitask_model
# 5                      allconv_01
# 6                 multitask_model
# 7                      allconv_01
# 8                 multitask_model
# 9                      allconv_01
# 90                multitask_model
# 91                    FCN_5_layer
# 92                    FCN_4_layer
# 93                    FCN_4_layer
# 100                   FCN_4_layer
# 101                   FCN_4_layer
# 102                   FCN_4_layer
# 103                   FCN_5_layer
# 104                   FCN_5_layer
# 105                   FCN_5_layer
# 106                   FCN_6_layer
# 107                   FCN_6_layer
# 117                   FCN_4_layer
# 118                   FCN_4_layer
# 119                   FCN_4_layer
# 120                   FCN_5_layer
# 121                   FCN_5_layer
# 122                   FCN_5_layer
# ...

# %%
condition =(df['Labels'] =="['Wonder', 'Transcendence', 'Nostalgia', 'Tenderness', 'Peacfulness', 'Joy', 'Power', 'Tension', 'Sadness']") 
# fcn6layer base
#0.2700907151137241
#fcn6layer dense + data aug
#0.3761
df[condition].sort_values('RMSE').head()
# Out:
#                             Model  \
# 556                   FCN_6_layer
# 538                   FCN_6_layer
# 568                   FCN_6_layer
# 169  Transfer_learning_embeddings
# 495                   FCN_6_layer
#
#                                                 Labels     lr loss_function  \
# 556  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.010           MAE
# 538  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.010           MAE
# 568  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.010           MAE
# 169  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.001           MAE
# 495  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.010           MAE
#
#      dense_weight_alpha  batch size  data_augmentation  snippet_duration_s  \
# 556                 0.0          50                  1            29.98576
# 538                 0.0          50                  2            29.98576
# ...

# %%
condition =(df['Labels'] =="['Wonder', 'Transcendence', 'Nostalgia', 'Tenderness', 'Peacfulness', 'Joy', 'Power', 'Tension', 'Sadness']")  & (df['oversampling']== False)& (df['loss_function']!= 'dense_weight') & (df['loss_function']!= 'dense_weight_tuned')  & (df['data_augmentation']== 0) & (df['loss_function'] == 'MAE') & (df['Model'].isin (['FCN_4_layer', 'FCN_5_layer', 'FCN_6_layer','FCN_7_layer']))


top_naive = df[condition].sort_values('RMSE')

# %%
top_naive[['Model', 'MAE', 'RMSE', 'R2']]
# Out:
#            Model       MAE      RMSE        R2
# 575  FCN_6_layer  4.662043  6.128331  0.313204
# 145  FCN_7_layer  4.900259  6.446189  0.276866
# 144  FCN_4_layer  4.914528  6.528900  0.230781
# 143  FCN_5_layer  4.998089  6.595715  0.237929

# %%
condition =(df['Labels'] == "['Wonder', 'Transcendence', 'Nostalgia', 'Tenderness', 'Peacfulness', 'Joy', 'Power', 'Tension', 'Sadness']")  & (df['oversampling']== False) & (df['data_augmentation']== 0) & (df['Model'].isin (['short_chunk_CNN']))


df[condition].sort_values('RMSE')
# Out:
#                Model                                             Labels    lr  \
# 176  short_chunk_CNN  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 174  short_chunk_CNN  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 175  short_chunk_CNN  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
#
#     loss_function  dense_weight_alpha  batch size  data_augmentation  \
# 176  dense_weight                 0.0          26                  0
# 174           MAE                 0.0          25                  0
# 175           MAE                 0.0          26                  0
#
#      snippet_duration_s  oversampling  oversampling_tolerance  \
# 176             3.58576         False                     0.0
# 174             2.98576         False                     0.0
# 175             3.58576         False                     0.0
#
#      oversampling_ratio oversampling_method        R2        ME       MAE  \
# ...

# %%
condition =(df['Labels'] == "['Wonder', 'Transcendence', 'Nostalgia', 'Tenderness', 'Peacfulness', 'Joy', 'Power', 'Tension', 'Sadness']")  & (df['oversampling']== False) & (df['data_augmentation']== 0) & (df['Model'].isin (['FCN_6_layer']))


df[condition].sort_values('RMSE')
# Out:
#            Model                                             Labels    lr  \
# 575  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 436  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 125  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 130  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 208  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 168  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 497  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 498  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 275  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 209  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 210  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
#
#           loss_function  dense_weight_alpha  batch size  data_augmentation  \
# ...

# %%
condition =(df['Labels'] == "['Wonder', 'Transcendence', 'Nostalgia', 'Tenderness', 'Peacfulness', 'Joy', 'Power', 'Tension', 'Sadness']")  & (df['oversampling']== False) & (df['data_augmentation']== 0) & (df['Model'].isin (['FCN_7_layer']))


df[condition].sort_values('RMSE')
# Out:
#            Model                                             Labels    lr  \
# 437  FCN_7_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 145  FCN_7_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 468  FCN_7_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 277  FCN_7_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 276  FCN_7_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
#
#     loss_function  dense_weight_alpha  batch size  data_augmentation  \
# 437           MSE                 0.0          50                  0
# 145           MAE                 0.0          50                  0
# 468  dense_weight                 1.0          50                  0
# 277  dense_weight                 2.0          50                  0
# 276  dense_weight                 1.5          50                  0
#
#      snippet_duration_s  oversampling  oversampling_tolerance  \
# ...

# %%
# condition =(df['Labels'] !="['Wonder', 'Transcendence', 'Nostalgia', 'Tenderness', 'Peacfulness', 'Joy', 'Power', 'Tension', 'Sadness']")  & (df['oversampling']== False)& (df['loss_function']== 'dense_weight') & (df['loss_function']!= 'dense_weight_tuned')  & (df['data_augmentation']== 0)& (df['Model'].isin (['FCN_4_layer', 'FCN_5_layer', 'FCN_6_layer','FCN_7_layer']))& (df['batch size']== 50) 


# df_single = df[condition].sort_values('RMSE')
# df_single

# %%
condition =(df['Labels'] =="['Wonder', 'Transcendence', 'Nostalgia', 'Tenderness', 'Peacfulness', 'Joy', 'Power', 'Tension', 'Sadness']")  & (df['oversampling']== False)& (df['loss_function']!= 'dense_weight') & (df['loss_function']!= 'dense_weight_tuned')  & (df['data_augmentation']== 0) & (df['loss_function'] == 'MAE') & (df['Model'].isin (['FCN_4_layer', 'FCN_5_layer', 'FCN_6_layer','FCN_7_layer']))


top_naive = df[condition].sort_values('RMSE')

# %%
condition =(df['Labels'] =="['Wonder', 'Transcendence', 'Nostalgia', 'Tenderness', 'Peacfulness', 'Joy', 'Power', 'Tension', 'Sadness']")  & (df['oversampling']== False)& (df['loss_function']!= 'dense_weight') & (df['loss_function']!= 'dense_weight_tuned')  & (df['data_augmentation']== 0) & (df['loss_function'] == 'MAE') & (df['Model'].isin (['pretrained_musicnn_parallel', 'musicnn_arch_finetune', 'FCN_6_layer','FCN_7_layer', 'musicnn_arch']))

#pretrained_musicnn_parallel 
#musicnn_arch_finetune finetuning pretrained model
top_musicnn = df[condition].sort_values('RMSE')
top_musicnn[['Model', 'MAE', 'RMSE', 'R2']]
# Out:
#                            Model       MAE      RMSE        R2
# 575                  FCN_6_layer  4.662043  6.128331  0.313204
# 145                  FCN_7_layer  4.900259  6.446189  0.276866
# 146  pretrained_musicnn_parallel  5.764174  7.649053 -0.010110
# 147        musicnn_arch_finetune  6.068561  7.864012 -0.055828
# 157                 musicnn_arch  6.082199  7.875947 -0.057253

# %%
# new_column_name = 'R2'
# new_column_value = 99

# # # # Use the insert method to add the new column at the specified location
# df.insert(12, new_column_name, new_column_value)
# #

df.tail(10)
# Out:
#            Model                                             Labels    lr  \
# 566  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 567  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 568  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 569  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 570  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 571  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 572  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 573  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 574  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 575  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
#
#     loss_function  dense_weight_alpha  batch size  data_augmentation  \
# 566           MAE                 0.0          50                  8
# ...

# %%
df = pd.read_csv('/home/ykinoshita/humrec_mood_tagger/mood_tagger_master_thesis_V2/performance/model_performance_list_detailed.csv')

# %%
condition =(df['Labels'].isin(["['Sadness']"]) )   &  (df['dense_weight_alpha']!= 0)& (df['loss_function']== 'dense_weight')& (df['data_augmentation']== 0)& (df['Model'].isin (['FCN_6_layer']))& (df['batch size']== 50) 
#, 'Transcendence', 'Nostalgia', 'Tenderness', 'Peacfulness', 'Joy', 'Power', 'Tension', 'Sadness']

df_single = df[condition].sort_values('RMSE')
df_single
# Out:
#            Model       Labels    lr loss_function  dense_weight_alpha  \
# 219  FCN_6_layer  ['Sadness']  0.01  dense_weight                 1.0
# 228  FCN_6_layer  ['Sadness']  0.01  dense_weight                 2.0
# 237  FCN_6_layer  ['Sadness']  0.01  dense_weight                 3.0
#
#      batch size  data_augmentation  snippet_duration_s  oversampling  \
# 219          50                  0            29.98576         False
# 228          50                  0            29.98576         False
# 237          50                  0            29.98576         False
#
#      oversampling_tolerance  oversampling_ratio oversampling_method        R2  \
# 219                     0.0                   0     No oversampling -0.434250
# 228                     0.0                   0     No oversampling -0.638831
# 237                     0.0                   0     No oversampling -0.905332
#
#            ME       MAE        MSE      RMSE  Wonder MAE  Transcendence MAE  \
# ...

# %%
condition =(df['Labels'].isin(["['Sadness']"]) )   & (df['data_augmentation']== 0)& (df['Model'].isin (['FCN_6_layer']))& (df['batch size']== 50) & (df['loss_function']== 'MAE') & (df['loss_function']== 'MAE')& (df['oversampling_method'].isin(['adaptive_density_oversampling' ,'adaptive_density_oversampling_V2']))
#, 'Transcendence', 'Nostalgia', 'Tenderness', 'Peacfulness', 'Joy', 'Power', 'Tension', 'Sadness'] 
#,"['Wonder', 'Transcendence', 'Nostalgia', 'Tenderness', 'Peacfulness', 'Joy', 'Power', 'Tension', 'Sadness']"
df_single = df[condition].sort_values('RMSE')
df_single
# Out:
#            Model       Labels    lr loss_function  dense_weight_alpha  \
# 345  FCN_6_layer  ['Sadness']  0.01           MAE                 0.0
# 297  FCN_6_layer  ['Sadness']  0.01           MAE                 0.0
# 318  FCN_6_layer  ['Sadness']  0.01           MAE                 0.0
# 288  FCN_6_layer  ['Sadness']  0.01           MAE                 0.0
# 315  FCN_6_layer  ['Sadness']  0.01           MAE                 0.0
# 306  FCN_6_layer  ['Sadness']  0.01           MAE                 0.0
#
#      batch size  data_augmentation  snippet_duration_s  oversampling  \
# 345          50                  0            29.98576          True
# 297          50                  0            29.98576          True
# 318          50                  0            29.98576          True
# 288          50                  0            29.98576          True
# 315          50                  0            29.98576          True
# ...

# %%
condition =(df['Labels'].isin(["['Sadness']","['Wonder', 'Transcendence', 'Nostalgia', 'Tenderness', 'Peacfulness', 'Joy', 'Power', 'Tension', 'Sadness']"]) ) & (df['oversampling']== False) & (df['data_augmentation']!= 0)& (df['Model'].isin (['FCN_6_layer']))& (df['batch size']== 50) & (df['loss_function']== 'MAE') 
#, 'Transcendence', 'Nostalgia', 'Tenderness', 'Peacfulness', 'Joy', 'Power', 'Tension', 'Sadness']

df_single = df[condition].sort_values('RMSE')
df_single
# Out:
#            Model                                             Labels    lr  \
# 501  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 500  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 499  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 504  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
#
#     loss_function  dense_weight_alpha  batch size  data_augmentation  \
# 501           MAE                 0.0          50                  4
# 500           MAE                 0.0          50                  2
# 499           MAE                 0.0          50                  1
# 504           MAE                 0.0          50                  8
#
#      snippet_duration_s  oversampling  oversampling_tolerance  \
# 501            29.98576         False                     0.0
# 500            29.98576         False                     0.0
# ...

# %%
condition =(df['Labels'].isin(["['Tenderness']","['Wonder', 'Transcendence', 'Nostalgia', 'Tenderness', 'Peacfulness', 'Joy', 'Power', 'Tension', 'Sadness']"]) )  & (df['oversampling']== False) & (df['data_augmentation']== 0)& (df['Model'].isin (['FCN_6_layer']))& (df['batch size']== 50) 
#, 'Transcendence', 'Nostalgia', 'Tenderness', 'Peacfulness', 'Joy', 'Power', 'Tension', 'Sadness']

df_single = df[condition].sort_values('Tenderness RMSE')
df_single
# Out:
#            Model                                             Labels    lr  \
# 130  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 575  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 436  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 151  FCN_6_layer                                     ['Tenderness']  0.01
# 214  FCN_6_layer                                     ['Tenderness']  0.01
# 349  FCN_6_layer                                     ['Tenderness']  0.01
# 125  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 232  FCN_6_layer                                     ['Tenderness']  0.01
# 223  FCN_6_layer                                     ['Tenderness']  0.01
# 208  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 210  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 209  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# ...

# %%
condition =(df['Labels'].isin(["['Transcendence']","['Wonder', 'Transcendence', 'Nostalgia', 'Tenderness', 'Peacfulness', 'Joy', 'Power', 'Tension', 'Sadness']"]) )&(df['data_augmentation']== 0)& (df['Model'].isin ([ 'FCN_6_layer']))& (df['batch size']== 50) 
#, 'Transcendence', 'Nostalgia', 'Tenderness', 'Peacfulness', 'Joy', 'Power', 'Tension', 'Sadness']

df_single = df[condition].sort_values('Transcendence RMSE')
df_single
# Out:
#            Model                                             Labels    lr  \
# 506  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 451  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 449  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 452  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 436  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 505  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 508  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 573  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 450  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 457  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 440  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 208  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# ...

# %%
condition =(df['Labels'].isin(["['Joy']"]) )& (df['oversampling']== False) & (df['data_augmentation']== 0)& (df['Model'].isin (['FCN_6_layer']))& (df['batch size']== 50)  & (df['loss_function']== 'dense_weight') & (df['dense_weight_alpha']!= 0) 
#, 'Transcendence', 'Nostalgia', 'Tenderness', 'Peacfulness', 'Joy', 'Power', 'Tension', 'Sadness']

df_single = df[condition].sort_values('RMSE')
df_single
# Out:
#            Model   Labels    lr loss_function  dense_weight_alpha  batch size  \
# 216  FCN_6_layer  ['Joy']  0.01  dense_weight                 1.0          50
# 234  FCN_6_layer  ['Joy']  0.01  dense_weight                 3.0          50
# 225  FCN_6_layer  ['Joy']  0.01  dense_weight                 2.0          50
#
#      data_augmentation  snippet_duration_s  oversampling  \
# 216                  0            29.98576         False
# 234                  0            29.98576         False
# 225                  0            29.98576         False
#
#      oversampling_tolerance  oversampling_ratio oversampling_method        R2  \
# 216                     0.0                   0     No oversampling -0.767167
# 234                     0.0                   0     No oversampling -1.681730
# 225                     0.0                   0     No oversampling -2.321860
#
#             ME        MAE         MSE       RMSE  Wonder MAE  \
# ...

# %%
condition =(df['Labels'] == "['Wonder', 'Transcendence', 'Nostalgia', 'Tenderness', 'Peacfulness', 'Joy', 'Power', 'Tension', 'Sadness']")  & (df['oversampling']== False)& (df['dense_weight_alpha']!= 0)  & (df['data_augmentation']== 0) & (df['Model'].isin (['Transfer_learning_embeddings']))


df[condition].sort_values('RMSE')
# Out:
#                             Model  \
# 438  Transfer_learning_embeddings
# 439  Transfer_learning_embeddings
# 238  Transfer_learning_embeddings
#
#                                                 Labels     lr loss_function  \
# 438  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.001           MSE
# 439  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.001           MAE
# 238  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.001  dense_weight
#
#      dense_weight_alpha  batch size  data_augmentation  snippet_duration_s  \
# 438                 2.0          10                  0                 3.0
# 439                 2.0          10                  0                 3.0
# 238                 2.0          10                  0                 3.0
#
#      oversampling  oversampling_tolerance  oversampling_ratio  \
# 438         False                     0.0                   0
# 439         False                     0.0                   0
# ...

# %%
condition =(df['Labels'] == "['Wonder', 'Transcendence', 'Nostalgia', 'Tenderness', 'Peacfulness', 'Joy', 'Power', 'Tension', 'Sadness']")  & (df['oversampling']== False) & (df['data_augmentation']== 0) & (df['Model'].isin (['allconv_01']))


df[condition].sort_values('RMSE')
# Out:
#          Model                                             Labels    lr  \
# 0   allconv_01  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 80  allconv_01  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 81  allconv_01  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 3   allconv_01  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 82  allconv_01  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 83  allconv_01  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 84  allconv_01  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 86  allconv_01  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 5   allconv_01  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 85  allconv_01  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 7   allconv_01  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 9   allconv_01  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
#
# ...

# %%
condition =(df['Labels'] == "['Wonder', 'Transcendence', 'Nostalgia', 'Tenderness', 'Peacfulness', 'Joy', 'Power', 'Tension', 'Sadness']")  & (df['R2'] != 99)

df[condition].sort_values('R2', ascending=False).head(15)
# Out:
#            Model                                             Labels    lr  \
# 556  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 568  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 538  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 495  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 515  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 487  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 525  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 555  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 567  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 536  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 501  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 573  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# ...

# %%
df.tail()
# Out:
#            Model                                             Labels    lr  \
# 571  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 572  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 573  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 574  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 575  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
#
#     loss_function  dense_weight_alpha  batch size  data_augmentation  \
# 571           MAE                 0.0          50                  0
# 572           MAE                 0.0          50                  0
# 573           MAE                 0.0          50                  0
# 574           MAE                 0.0          50                  0
# 575           MAE                 0.0          50                  0
#
#      snippet_duration_s  oversampling  oversampling_tolerance  \
# ...

# %%
condition =(df['Labels'] =="['Wonder', 'Transcendence', 'Nostalgia', 'Tenderness', 'Peacfulness', 'Joy', 'Power', 'Tension', 'Sadness']")   & (df['data_augmentation']== 0)& (df['Model'].isin (['FCN_6_layer']))& (df['batch size']== 50) & (df['oversampling_method'].isin(['average_density_oversampling','average_density_oversampling_V2','average_density_oversampling_V3','minimum_density_oversampling']) ) & (df['loss_function']== 'MAE')


df[condition].sort_values('RMSE')
# Out:
#            Model                                             Labels    lr  \
# 573  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 461  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 449  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 443  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 440  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 442  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 460  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 455  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 445  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 446  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 448  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 451  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# ...

# %%
condition =(df['Labels'] !="['Wonder', 'Transcendence', 'Nostalgia', 'Tenderness', 'Peacfulness', 'Joy', 'Power', 'Tension', 'Sadness']")   & (df['data_augmentation']== 0)& (df['Model'].isin (['FCN_6_layer']))& (df['batch size']== 50) & (df['oversampling_method'].isin(['density_oversampling_V2', 'density_oversampling_V3']) ) & (df['loss_function']== 'MAE')


df_single = df[condition].sort_values('Sadness RMSE')
df_single.groupby(['loss_function', 'lr','Model','data_augmentation','snippet_duration_s','oversampling','oversampling_tolerance','oversampling_ratio','oversampling_method'])['RMSE'].mean()
# Out:
# loss_function  lr    Model        data_augmentation  snippet_duration_s  oversampling  oversampling_tolerance  oversampling_ratio  oversampling_method
# MAE            0.01  FCN_6_layer  0                  29.98576            True          0.3                     1                   density_oversampling_V2    6.315821
#                                                                                                                                    density_oversampling_V3    6.578720
#                                                                                        0.4                     1                   density_oversampling_V3    8.822568
#                                                                                        0.5                     1                   density_oversampling_V2    6.410322
#                                                                                                                                    density_oversampling_V3    6.613503
# ...

# %%
condition =(df['Labels'] =="['Wonder', 'Transcendence', 'Nostalgia', 'Tenderness', 'Peacfulness', 'Joy', 'Power', 'Tension', 'Sadness']")   & (df['data_augmentation']== 0)& (df['Model'].isin (['FCN_6_layer']))& (df['batch size']== 50)  & (df['loss_function']== 'MAE')
df_single = df[condition].sort_values('RMSE')
df_single
# Out:
#            Model                                             Labels    lr  \
# 573  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 461  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 449  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 443  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 440  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 442  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 460  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 455  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 445  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 446  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 448  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 505  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# ...

# %%
condition =(df['Labels'] =="['Wonder', 'Transcendence', 'Nostalgia', 'Tenderness', 'Peacfulness', 'Joy', 'Power', 'Tension', 'Sadness']")   & (df['data_augmentation']== 0)& (df['Model'].isin (['FCN_6_layer']))& (df['batch size']== 50)  & (df['loss_function'].isin(['dense_weight_tuned','dense_weight'])) #& (df['dense_weight_alpha'] != 0)
df_single = df[condition].sort_values('RMSE') 
df_single
#df['loss_function'].unique()
# Out:
#            Model                                             Labels    lr  \
# 208  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 497  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 498  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 275  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 209  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 210  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
#
#           loss_function  dense_weight_alpha  batch size  data_augmentation  \
# 208        dense_weight                 0.0          50                  0
# 497        dense_weight                 1.0          50                  0
# 498  dense_weight_tuned                 0.0          50                  0
# 275        dense_weight                 1.5          50                  0
# ...

# %%
condition =(df['Labels'] !="['Wonder', 'Transcendence', 'Nostalgia', 'Tenderness', 'Peacfulness', 'Joy', 'Power', 'Tension', 'Sadness']")   & (df['data_augmentation']== 0)& (df['Model'].isin (['FCN_6_layer']))& (df['batch size']== 50)  & (df['loss_function']== 'MAE') & (df['oversampling']== True) & (df['oversampling_method']== 'density_oversampling_V2') 
df_single = df[condition].sort_values('RMSE') 
df_single
# Out:
#            Model             Labels    lr loss_function  dense_weight_alpha  \
# 433  FCN_6_layer        ['Sadness']  0.01           MAE                 0.0
# 477  FCN_6_layer        ['Sadness']  0.01           MAE                 0.0
# 415  FCN_6_layer        ['Sadness']  0.01           MAE                 0.0
# 408  FCN_6_layer  ['Transcendence']  0.01           MAE                 0.0
# 426  FCN_6_layer  ['Transcendence']  0.01           MAE                 0.0
# 470  FCN_6_layer  ['Transcendence']  0.01           MAE                 0.0
# 472  FCN_6_layer     ['Tenderness']  0.01           MAE                 0.0
# 410  FCN_6_layer     ['Tenderness']  0.01           MAE                 0.0
# 427  FCN_6_layer      ['Nostalgia']  0.01           MAE                 0.0
# 425  FCN_6_layer         ['Wonder']  0.01           MAE                 0.0
# 471  FCN_6_layer      ['Nostalgia']  0.01           MAE                 0.0
# ...

# %%
condition =(df['Labels'] !="['Wonder', 'Transcendence', 'Nostalgia', 'Tenderness', 'Peacfulness', 'Joy', 'Power', 'Tension', 'Sadness']")   & (df['data_augmentation']== 0)& (df['Model'].isin (['FCN_6_layer']))& (df['batch size']== 50)  & (df['loss_function']== 'MAE') & (df['oversampling']== True) & (df['oversampling_method']== 'density_oversampling_V3') 
df_single = df[condition].sort_values('Labels') 
df_single
# Out:
#            Model             Labels    lr loss_function  dense_weight_alpha  \
# 483  FCN_6_layer            ['Joy']  0.01           MAE                 0.0
# 403  FCN_6_layer            ['Joy']  0.01           MAE                 0.0
# 421  FCN_6_layer            ['Joy']  0.01           MAE                 0.0
# 327  FCN_6_layer      ['Nostalgia']  0.01           MAE                 0.0
# 400  FCN_6_layer      ['Nostalgia']  0.01           MAE                 0.0
# 480  FCN_6_layer      ['Nostalgia']  0.01           MAE                 0.0
# 418  FCN_6_layer      ['Nostalgia']  0.01           MAE                 0.0
# 482  FCN_6_layer    ['Peacfulness']  0.01           MAE                 0.0
# 402  FCN_6_layer    ['Peacfulness']  0.01           MAE                 0.0
# 420  FCN_6_layer    ['Peacfulness']  0.01           MAE                 0.0
# 326  FCN_6_layer          ['Power']  0.01           MAE                 0.0
# ...

# %%
condition =(df['Labels'].isin(["['Wonder']"]) )   & (df['data_augmentation']== 0)& (df['Model'].isin (['FCN_6_layer']))& (df['batch size']== 50) & (df['loss_function']== 'MAE') & (df['oversampling_method'].isin(['density_oversampling_V3','density_oversampling_V2']))
#, 'Transcendence', 'Nostalgia', 'Tenderness', 'Peacfulness', 'Joy', 'Power', 'Tension', 'Sadness'] 
#,"['Wonder', 'Transcendence', 'Nostalgia', 'Tenderness', 'Peacfulness', 'Joy', 'Power', 'Tension', 'Sadness']"
df_single = df[condition].sort_values('RMSE')
df_single
# Out:
#            Model      Labels    lr loss_function  dense_weight_alpha  \
# 425  FCN_6_layer  ['Wonder']  0.01           MAE                 0.0
# 398  FCN_6_layer  ['Wonder']  0.01           MAE                 0.0
# 469  FCN_6_layer  ['Wonder']  0.01           MAE                 0.0
# 478  FCN_6_layer  ['Wonder']  0.01           MAE                 0.0
# 407  FCN_6_layer  ['Wonder']  0.01           MAE                 0.0
# 416  FCN_6_layer  ['Wonder']  0.01           MAE                 0.0
#
#      batch size  data_augmentation  snippet_duration_s  oversampling  \
# 425          50                  0            29.98576          True
# 398          50                  0            29.98576          True
# 469          50                  0            29.98576          True
# 478          50                  0            29.98576          True
# 407          50                  0            29.98576          True
# ...

# %%
condition =(df['Labels'].isin(["['Nostalgia']"]) )   & (df['data_augmentation']== 0)& (df['Model'].isin (['FCN_6_layer']))& (df['batch size']== 50) & (((df['loss_function']== 'dense_weight')& (df['dense_weight_alpha'] != 0)) | (df['loss_function']== 'MAE'))& (df['oversampling'] == False) 
#, 'Transcendence', 'Nostalgia', 'Tenderness', 'Peacfulness', 'Joy', 'Power', 'Tension', 'Sadness'] 
#,"['Wonder', 'Transcendence', 'Nostalgia', 'Tenderness', 'Peacfulness', 'Joy', 'Power', 'Tension', 'Sadness']"
df_single = df[condition].sort_values('RMSE')
df_single
# Out:
#            Model         Labels    lr loss_function  dense_weight_alpha  \
# 213  FCN_6_layer  ['Nostalgia']  0.01  dense_weight                 1.0
# 150  FCN_6_layer  ['Nostalgia']  0.01           MAE                 0.0
# 222  FCN_6_layer  ['Nostalgia']  0.01  dense_weight                 2.0
# 231  FCN_6_layer  ['Nostalgia']  0.01  dense_weight                 3.0
#
#      batch size  data_augmentation  snippet_duration_s  oversampling  \
# 213          50                  0            29.98576         False
# 150          50                  0            29.98576         False
# 222          50                  0            29.98576         False
# 231          50                  0            29.98576         False
#
#      oversampling_tolerance  oversampling_ratio oversampling_method        R2  \
# 213                     0.0                   0     No oversampling  0.401448
# 150                     0.0                   0     No oversampling  0.011342
# ...

# %%
condition =(df['Labels'] =="['Wonder', 'Transcendence', 'Nostalgia', 'Tenderness', 'Peacfulness', 'Joy', 'Power', 'Tension', 'Sadness']")   & (df['Model'].isin (['FCN_6_layer'])) & (df['loss_function']== 'MAE') & (df['oversampling']== True) & (df['oversampling_method'].isin(['density_oversampling_augmentation_V2','density_oversampling_augmentation','non_average_density_oversampling_augmentation'])) 
df_single = df[condition].sort_values('RMSE') 
df_single.head(10)
# Out:
#            Model                                             Labels    lr  \
# 556  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 538  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 495  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 515  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 536  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 555  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 531  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 525  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 539  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 513  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
#
#     loss_function  dense_weight_alpha  batch size  data_augmentation  \
# 556           MAE                 0.0          50                  1
# ...

# %%
condition =(df['Labels'] =="['Wonder', 'Transcendence', 'Nostalgia', 'Tenderness', 'Peacfulness', 'Joy', 'Power', 'Tension', 'Sadness']")   & (df['Model'].isin (['FCN_6_layer'])) & (df['loss_function']== 'MAE') & (df['oversampling']== True) & (df['oversampling_method'].isin(['average_density_oversampling_V2','average_density_oversampling'])) 
df_single = df[condition].sort_values('RMSE') 
df_single.head(10)
# Out:
#            Model                                             Labels    lr  \
# 573  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 461  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 449  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 443  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 440  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 442  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 455  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 445  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 446  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 448  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
#
#     loss_function  dense_weight_alpha  batch size  data_augmentation  \
# 573           MAE                 0.0          50                  0
# ...

# %%
df.tail(15)
# Out:
#            Model                                             Labels    lr  \
# 561  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 562  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 563  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 564  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 565  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 566  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 567  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 568  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 569  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 570  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 571  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 572  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# ...

# %%
r = []
rmse = []

lossfunc = []
for i in ['Wonder', 'Transcendence', 'Nostalgia', 'Tenderness', 'Peacfulness', 'Joy', 'Power', 'Tension', 'Sadness']:
    condition =(df['Labels'].isin([f"['{i}']"]) )   & (df['data_augmentation']== 0)& (df['Model'].isin (['FCN_6_layer']))& (df['batch size']== 50) & (((df['loss_function']== 'dense_weight')& (df['dense_weight_alpha'] != 0)) | (df['loss_function']== 'MAE'))& (df['oversampling'] == False) 
    df_single = df[condition].sort_values('RMSE')

    r.append(list(df_single['R2'])[0])
    rmse.append(list(df_single['RMSE'])[0])
    lossfunc.append(list(df_single['loss_function'])[0])

print(sum(r) / len(r) )
# Out:
# 0.27788355246687413

# %%
lossfunc
# Out:
# ['MAE',
#  'MAE',
#  'dense_weight',
#  'MAE',
#  'MAE',
#  'MAE',
#  'dense_weight',
#  'dense_weight',
#  'MAE']

# %%
r
# Out:
# [0.042304100309041,
#  0.3357397546398053,
#  0.4014480622687318,
#  0.3474756104347857,
#  0.560818688085454,
#  0.2424356062444208,
#  0.2932258628139818,
#  0.20133361604149,
#  0.0761706713641569]

# %%
rmse
# Out:
# [6.376070976257324,
#  4.158624172210693,
#  6.713286876678467,
#  5.574755668640137,
#  6.738268852233887,
#  9.458937644958496,
#  7.838854312896728,
#  6.86893367767334,
#  3.485402107238769]

# %%
print(sum(rmse) / len(rmse) )
# Out:
# 6.357014920976427

# %%
r = []
rmse = []

lossfunc = []
for i in ['Wonder', 'Transcendence', 'Nostalgia', 'Tenderness', 'Peacfulness', 'Joy', 'Power', 'Tension', 'Sadness']:
    condition =(df['Labels'].isin([f"['{i}']"]) )   & (df['data_augmentation']== 0)& (df['Model'].isin (['FCN_6_layer']))& (df['batch size']== 50) & ((df['loss_function']== 'dense_weight')& (df['dense_weight_alpha'] != 0)) & (df['oversampling'] == False) 
    df_single = df[condition].sort_values('RMSE')

    r.append(list(df_single['R2'])[0])
    rmse.append(list(df_single['RMSE'])[0])
    lossfunc.append(list(df_single['loss_function'])[0])

print(sum(r) / len(r) )
# Out:
# -0.012476440232788925

# %%
r
# Out:
# [-0.3294319783561985,
#  0.2365597001810599,
#  0.4014480622687318,
#  0.3090062722805288,
#  -0.0230125493683341,
#  -0.7671666242211124,
#  0.2932258628139818,
#  0.20133361604149,
#  -0.4342503237352477]

# %%
condition =(df['Labels'] == "['Wonder', 'Transcendence', 'Nostalgia', 'Tenderness', 'Peacfulness', 'Joy', 'Power', 'Tension', 'Sadness']")  & (df['oversampling']== False) & (df['data_augmentation']!= 0) & (df['Model'].isin (['FCN_6_layer']))& (df['loss_function']== 'MAE')


df[condition].sort_values('RMSE')
# Out:
#            Model                                             Labels    lr  \
# 501  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 500  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 499  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 504  FCN_6_layer  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
#
#     loss_function  dense_weight_alpha  batch size  data_augmentation  \
# 501           MAE                 0.0          50                  4
# 500           MAE                 0.0          50                  2
# 499           MAE                 0.0          50                  1
# 504           MAE                 0.0          50                  8
#
#      snippet_duration_s  oversampling  oversampling_tolerance  \
# 501            29.98576         False                     0.0
# 500            29.98576         False                     0.0
# ...

# %%
condition =(df['Labels'].isin(["['Sadness']","['Wonder', 'Transcendence', 'Nostalgia', 'Tenderness', 'Peacfulness', 'Joy', 'Power', 'Tension', 'Sadness']"]) ) & (df['oversampling']== False) & (df['data_augmentation']== 0)& (df['Model'].isin (['short_chunk_CNN']))
#, 'Transcendence', 'Nostalgia', 'Tenderness', 'Peacfulness', 'Joy', 'Power', 'Tension', 'Sadness']

df_single = df[condition].sort_values('RMSE')
df_single
# Out:
#                Model                                             Labels    lr  \
# 176  short_chunk_CNN  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 174  short_chunk_CNN  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
# 175  short_chunk_CNN  ['Wonder', 'Transcendence', 'Nostalgia', 'Tend...  0.01
#
#     loss_function  dense_weight_alpha  batch size  data_augmentation  \
# 176  dense_weight                 0.0          26                  0
# 174           MAE                 0.0          25                  0
# 175           MAE                 0.0          26                  0
#
#      snippet_duration_s  oversampling  oversampling_tolerance  \
# 176             3.58576         False                     0.0
# 174             2.98576         False                     0.0
# 175             3.58576         False                     0.0
#
#      oversampling_ratio oversampling_method        R2        ME       MAE  \
# ...

# %%
import pandas as pd
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

pd.read_csv("/home/ykinoshita/humrec_mood_tagger/output_fold/FCN_6_layer/No_oversampling/fold_metrics_detailed.csv")['R2']
# Out:
# 0    0.207979
# 1    0.278237
# 2    0.233544
# 3    0.229514
# 4    0.097110
# 5    0.207561
# 6    0.296895
# 7    0.297236
# 8    0.396009
# 9    0.295409
# Name: R2, dtype: float64

# %%
import pandas as pd
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

pd.read_csv("/home/ykinoshita/humrec_mood_tagger/output_fold/FCN_6_layer/density_oversampling_augmentation_V2_0.6_1/fold_metrics_detailed.csv")['R2']
# Out:
# 0    0.046363
# 1    0.297421
# 2    0.227391
# 3    0.225306
# 4    0.111714
# 5    0.204251
# 6    0.254686
# 7    0.299877
# 8    0.400270
# 9    0.252196
# Name: R2, dtype: float64

# %%
pd.read_csv('/home/ykinoshita/humrec_mood_tagger/output_fold/FCN_6_layer/density_oversampling_augmentation_ALL_0.6_2/fold_metrics_detailed.csv')['R2']
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 pd.read_csv('/home/ykinoshita/humrec_mood_tagger/output_fold/FCN_6_layer/density_oversampling_augmentation_ALL_0.6_2/fold_metrics_detailed.csv')['R2']
#
# ...

# %% [markdown]
# Baseline

# %%
data = pd.read_csv('/home/ykinoshita/humrec_mood_tagger/output_fold/FCN_6_layer/No_oversampling/fold_metrics_detailed.csv')

print(f"R2: {data['R2']}")
print(f"RMSE: {data['RMSE']}")
print(f"Average R2: {data['R2'].mean()}")
print(f"Average RMSE: {data['RMSE'].mean()}")
print(f"Max R2: {data['R2'].max()}")
print(f"Min R2: {data['R2'].min()}")
# Out:
# R2: 0    0.207979
# 1    0.278237
# 2    0.233544
# 3    0.229514
# 4    0.097110
# 5    0.207561
# 6    0.296895
# 7    0.297236
# 8    0.396009
# 9    0.295409
# Name: R2, dtype: float64
# RMSE: 0    6.511482
# 1    6.539495
# 2    6.072861
# 3    5.627192
# 4    6.294391
# 5    6.522257
# 6    6.467844
# 7    6.575991
# 8    6.371692
# 9    6.544493
# Name: RMSE, dtype: float64
# Average R2: 0.25394934048739265
# Average RMSE: 6.352769780123902
# Max R2: 0.3960085576614942
# Min R2: 0.0971098746819229

# %% [markdown]
# DOMR aug 2 t 0.5

# %%
pd.read_csv('/home/ykinoshita/humrec_mood_tagger/output_fold/FCN_6_layer/density_oversampling_augmentation_0.5_2/fold_metrics_detailed.csv')['R2']
print(f"R2: {data['R2']}")
print(f"RMSE: {data['RMSE']}")
print(f"Average R2: {data['R2'].mean()}")
print(f"Average RMSE: {data['RMSE'].mean()}")
print(f"Max R2: {data['R2'].max()}")
print(f"Min R2: {data['R2'].min()}")
# Out:
# 0    0.224997
# 1    0.281951
# 2    0.200436
# 3    0.290414
# 4    0.254657
# 5    0.181191
# 6    0.246229
# 7    0.172188
# 8    0.204100
# 9    0.260784
# Name: R2, dtype: float64
# R2: 0    0.342446
# 1    0.249025
# 2    0.287476
# 3    0.156353
# 4    0.275295
# 5    0.202624
# 6    0.261115
# 7    0.286282
# 8    0.259494
# 9    0.206267
# Name: R2, dtype: float64
# RMSE: 0    6.363478
# 1    6.746445
# 2    6.600424
# 3    7.059440
# 4    6.605210
# 5    6.904353
# 6    6.661426
# 7    6.562156
# 8    6.717622
# 9    6.927579
# Name: RMSE, dtype: float64
# Average R2: 0.252637555950011
# Average RMSE: 6.7148132317309575
# Max R2: 0.3424461349761385
# Min R2: 0.156352699082156

# %% [markdown]
# FCN6 DOMR percentile

# %%
data = pd.read_csv('/home/ykinoshita/humrec_mood_tagger/output_fold/FCN_6_layer/average_density_oversampling_V2_0.6/fold_metrics_detailed.csv')

print(f"R2: {data['R2']}")
print(f"RMSE: {data['RMSE']}")
print(f"Average R2: {data['R2'].mean()}")
print(f"Average RMSE: {data['RMSE'].mean()}")
print(f"Max R2: {data['R2'].max()}")
print(f"Min R2: {data['R2'].min()}")
# Out:
# R2: 0    0.184917
# 1    0.157142
# 2    0.245320
# 3    0.257820
# 4    0.281634
# 5    0.180649
# 6    0.242644
# 7    0.211955
# 8    0.245944
# 9    0.213384
# Name: R2, dtype: float64
# RMSE: 0    7.020361
# 1    7.030611
# 2    6.756134
# 3    6.692667
# 4    6.608691
# 5    6.970280
# 6    6.760532
# 7    6.884506
# 8    6.704644
# 9    6.883835
# Name: RMSE, dtype: float64
# Average R2: 0.2221409052051766
# Average RMSE: 6.8312259727417
# Max R2: 0.2816340136015872
# Min R2: 0.1571419175359758

# %%
# Out:
# R2: 0    0.342446
# 1    0.249025
# 2    0.287476
# 3    0.156353
# 4    0.275295
# 5    0.202624
# 6    0.261115
# 7    0.286282
# 8    0.259494
# 9    0.206267
# Name: R2, dtype: float64
# RMSE: 0    6.363478
# 1    6.746445
# 2    6.600424
# 3    7.059440
# 4    6.605210
# 5    6.904353
# 6    6.661426
# 7    6.562156
# 8    6.717622
# 9    6.927579
# Name: RMSE, dtype: float64
# Average R2: 0.252637555950011
# Average RMSE: 6.7148132317309575
# Max R2: 0.3424461349761385
# Min R2: 0.156352699082156

# %% [markdown]
# DT1

# %%
data = pd.read_csv('/home/ykinoshita/humrec_mood_tagger/output_fold/FCN_6_layer/No_oversampling_1/fold_metrics_detailed.csv')
print(f"R2: {data['R2']}")
print(f"RMSE: {data['RMSE']}")
print(f"Average R2: {data['R2'].mean()}")
print(f"Average RMSE: {data['RMSE'].mean()}")
print(f"Max R2: {data['R2'].max()}")
print(f"Min R2: {data['R2'].min()}")
# Out:
# R2: 0    0.273467
# 1    0.261845
# 2    0.229282
# 3    0.250348
# 4    0.267399
# 5    0.263322
# 6    0.203698
# 7    0.248476
# 8    0.285673
# 9    0.284253
# Name: R2, dtype: float64
# RMSE: 0    6.664920
# 1    6.726832
# 2    6.875504
# 3    6.753875
# 4    6.657942
# 5    6.708941
# 6    6.999494
# 7    6.758089
# 8    6.572330
# 9    6.603399
# Name: RMSE, dtype: float64
# Average R2: 0.25677619381596944
# Average RMSE: 6.732132497207641
# Max R2: 0.2856725870944718
# Min R2: 0.2036977990121443

# %% [markdown]
# DT2

# %%
data = pd.read_csv('/home/ykinoshita/humrec_mood_tagger/output_fold/FCN_6_layer/No_oversampling_2/fold_metrics_detailed.csv')
print(f"R2: {data['R2']}")
print(f"RMSE: {data['RMSE']}")
print(f"Average R2: {data['R2'].mean()}")
print(f"Average RMSE: {data['RMSE'].mean()}")
print(f"Max R2: {data['R2'].max()}")
print(f"Min R2: {data['R2'].min()}")
# Out:
# 0    0.258999
# 1    0.289563
# 2    0.271592
# 3    0.228386
# 4    0.265125
# 5    0.367122
# 6    0.211199
# 7    0.318817
# 8    0.272800
# 9    0.301858
# Name: R2, dtype: float64
# R2: 0.2785461686976153
# RMSE: 6.627799653174438
# Max R2: 0.3671222799989619
# Min R2: 0.211199214784772

# %% [markdown]
# DT4

# %%
data = pd.read_csv('/home/ykinoshita/humrec_mood_tagger/output_fold/FCN_6_layer/No_oversampling_4/fold_metrics_detailed.csv')
print(f"R2: {data['R2']}")
print(f"RMSE: {data['RMSE']}")
print(f"Average R2: {data['R2'].mean()}")
print(f"Average RMSE: {data['RMSE'].mean()}")
print(f"Max R2: {data['R2'].max()}")
print(f"Min R2: {data['R2'].min()}")
# Out:
# 0    0.086546
# 1    0.245141
# 2    0.254284
# 3    0.290579
# 4    0.142419
# 5    0.187024
# 6    0.214687
# 7    0.294632
# 8    0.247671
# 9    0.237319
# Name: R2, dtype: float64
# R2: 0.2200302449014316
# RMSE: 6.846132134814454
# Max R2: 0.2946317600141881
# Min R2: 0.0865461464578529

# %% [markdown]
# FCN6 DOMR+ percentile aug 1

# %%
data = pd.read_csv('/home/ykinoshita/humrec_mood_tagger/output_fold/FCN_6_layer/density_oversampling_augmentation_V2_0.7_1/fold_metrics_detailed.csv')
print(f"R2: {data['R2']}")
print(f"RMSE: {data['RMSE']}")
print(f"Average R2: {data['R2'].mean()}")
print(f"Average RMSE: {data['RMSE'].mean()}")
print(f"Max R2: {data['R2'].max()}")
print(f"Min R2: {data['R2'].min()}")
# Out:
# R2: 0    0.342446
# 1    0.249025
# 2    0.287476
# 3    0.156353
# 4    0.275295
# 5    0.202624
# 6    0.261115
# 7    0.286282
# 8    0.259494
# 9    0.206267
# Name: R2, dtype: float64
# RMSE: 0    6.363478
# 1    6.746445
# 2    6.600424
# 3    7.059440
# 4    6.605210
# 5    6.904353
# 6    6.661426
# 7    6.562156
# 8    6.717622
# 9    6.927579
# Name: RMSE, dtype: float64
# Average R2: 0.252637555950011
# Average RMSE: 6.7148132317309575
# Max R2: 0.3424461349761385
# Min R2: 0.156352699082156

# %% [markdown]
# FCN6 DOMR+ aug 2 0.6

# %%
data = pd.read_csv('/home/ykinoshita/humrec_mood_tagger/output_fold/FCN_6_layer/density_oversampling_augmentation_0.6_2/fold_metrics_detailed.csv')
print(f"R2: {data['R2']}")
print(f"RMSE: {data['RMSE']}")
print(f"Average R2: {data['R2'].mean()}")
print(f"Average RMSE: {data['RMSE'].mean()}")
print(f"Max R2: {data['R2'].max()}")
print(f"Min R2: {data['R2'].min()}")
# Out:
# 0    0.282931
# 1    0.288601
# 2    0.283857
# 3    0.229195
# 4    0.236861
# 5    0.295512
# 6    0.293954
# 7    0.245864
# 8    0.231921
# 9    0.201574
# Name: R2, dtype: float64
# R2: 0.2590268394774339
# RMSE: 6.710350279685668
# Max R2: 0.295511819886619
# Min R2: 0.2015735515739931

# %% [markdown]
# FCN6 DOMR+ percentile aug 4 0.7

# %%
data = pd.read_csv('/home/ykinoshita/humrec_mood_tagger/output_fold/FCN_6_layer/density_oversampling_augmentation_V2_0.7_4/fold_metrics_detailed.csv')
print(f"R2: {data['R2']}")
print(f"RMSE: {data['RMSE']}")
print(f"Average R2: {data['R2'].mean()}")
print(f"Average RMSE: {data['RMSE'].mean()}")
print(f"Max R2: {data['R2'].max()}")
print(f"Min R2: {data['R2'].min()}")
# Out:
# R2: 0    0.240798
# 1    0.240331
# 2    0.171364
# 3    0.229383
# 4    0.209024
# 5    0.287676
# 6    0.241326
# 7    0.269223
# 8    0.255533
# 9    0.205666
# Name: R2, dtype: float64
# RMSE: 0    6.712168
# 1    6.752521
# 2    7.081481
# 3    6.818140
# 4    6.911949
# 5    6.591717
# 6    6.744512
# 7    6.649096
# 8    6.692008
# 9    6.952913
# Name: RMSE, dtype: float64
# Average R2: 0.235032440321764
# Average RMSE: 6.790650220698853
# Max R2: 0.2876756976063873
# Min R2: 0.1713643375574099

# %%
data = pd.read_csv('/home/ykinoshita/humrec_mood_tagger/output_fold/FCN_6_layer/density_oversampling_augmentation_0.6_4/fold_metrics_detailed.csv')
print(f"R2: {data['R2']}")
print(f"RMSE: {data['RMSE']}")
print(f"Average R2: {data['R2'].mean()}")
print(f"Average RMSE: {data['RMSE'].mean()}")
print(f"Max R2: {data['R2'].max()}")
print(f"Min R2: {data['R2'].min()}")
# Out:
# R2: 0    0.264606
# 1    0.246840
# 2    0.253498
# 3    0.247902
# 4    0.221304
# 5    0.223907
# 6    0.218374
# 7    0.193489
# 8    0.283009
# 9    0.298400
# Name: R2, dtype: float64
# RMSE: 0    6.665651
# 1    6.730349
# 2    6.723315
# 3    6.748744
# 4    6.879760
# 5    6.905175
# 6    6.875501
# 7    6.962560
# 8    6.615122
# 9    6.554090
# Name: RMSE, dtype: float64
# Average R2: 0.24513280101678533
# Average RMSE: 6.766026685480957
# Max R2: 0.2983998636353815
# Min R2: 0.1934890053863197

# %%
data = pd.read_csv("/home/ykinoshita/humrec_mood_tagger/output_fold/FCN_6_layer/non_average_density_oversampling_augmentation_0.3_1/fold_metrics_detailed.csv")
print(f"R2: {data['R2']}")
print(f"RMSE: {data['RMSE']}")
print(f"Average R2: {data['R2'].mean()}")
print(f"Average RMSE: {data['RMSE'].mean()}")
print(f"Max R2: {data['R2'].max()}")
print(f"Min R2: {data['R2'].min()}")
# Out:
# R2: 0    0.271700
# 1    0.278346
# 2    0.267892
# 3    0.309578
# 4    0.316731
# 5    0.281517
# 6    0.302932
# 7    0.328926
# 8    0.336016
# 9    0.317077
# Name: R2, dtype: float64
# RMSE: 0    6.687514
# 1    6.680391
# 2    6.713398
# 3    6.507954
# 4    6.410086
# 5    6.641653
# 6    6.566336
# 7    6.417108
# 8    6.314196
# 9    6.439743
# Name: RMSE, dtype: float64
# Average R2: 0.30107174247220997
# Average RMSE: 6.537837886298829
# Max R2: 0.3360164621479352
# Min R2: 0.2678922731868042
